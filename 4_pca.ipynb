# %% [markdown]
# Now we want to reduce the dimensionality of the proteomic data.
# First, we retrieve the stored data.

# %%
# %store -r normal_patients
# %store -r normal_prot
# %store -r all_patients
# %store -r all_prot

# %%
import numpy as np
import pandas as pd
# %conda install scikit-learn
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print(all_prot.max().max())
print(all_prot.min().min())
# Out:
# 7.796314684465253
# -7.985884888123239

# %% [markdown]
# We want our data to be normalized for PCA. The data is pretty widely spread. However, negative values mean it's not just raw expression data. It's likely been transformed already.
# Let's do some more math to see what we're looking at.

# %%
prot_dist_stats = all_prot.describe().T[['mean','std']]
print(prot_dist_stats['mean'].min())
print(prot_dist_stats['mean'].max())
print(prot_dist_stats['std'].min())
print(prot_dist_stats['std'].max())
# Out:
# -4.533969510866671
# 2.0996212270047736
# 0.11167970676536301
# 2.98387673374958

# %% [markdown]
# This indicates the data has probably been centered, but not normalized.
# Let's scale each protein to be normalized.

# %%
scaler = StandardScaler()
prot_scaled = pd.DataFrame(
    scaler.fit_transform(all_prot), 
    index=all_prot.index, 
    columns=all_prot.columns
)
prot_scaled
# Out:
# /opt/anaconda3/envs/bio362/lib/python3.11/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/anaconda3/envs/bio362/lib/python3.11/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/anaconda3/envs/bio362/lib/python3.11/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# Name                     ARF5              M6PR             ESRRA  \
# Database_ID ENSP00000000233.5 ENSP00000000412.3 ENSP00000000442.6
# Patient_ID
# 01BR001              0.188284         -1.814247               NaN
# 01BR008             -1.236712          1.437186          0.421297
# 01BR009             -0.415389          0.173460          0.755232
# 01BR010              0.440114          1.180979         -0.808225
# 01BR015             -1.222947         -1.648399               NaN
# ...                       ...               ...               ...
# 21BR010              1.584004          0.074477         -1.196397
# 22BR005             -1.331816          0.679751               NaN
# 22BR006              1.064039          0.660140               NaN
# CPT000814           -1.249180          0.976071          0.527714
# CPT001846            1.920034         -0.011732          1.710314
#
# Name                    FKBP4           NDUFAF7             FUCA2  \
# Database_ID ENSP00000001008.4 ENSP00000002125.4 ENSP00000002165.5
# Patient_ID
# 01BR001             -0.666932          2.888948         -0.752438
# 01BR008             -0.807571          1.120189         -1.032339
# 01BR009             -0.506623          3.217055         -0.938549
# 01BR010             -1.287785          0.434174         -0.727899
# 01BR015             -0.008252         -0.588847         -0.557360
# ...                       ...               ...               ...
# 21BR010             -0.075532         -0.002527          1.122262
# 22BR005              1.247367         -0.449744          0.138453
# 22BR006             -0.454233          0.008209          1.167842
# CPT000814            0.446050          1.418448         -1.784575
# CPT001846           -1.805980          1.301903          0.264146
#
# Name                   DBNDD1            SEMA3F              CFTR  \
# Database_ID ENSP00000002501.6 ENSP00000002829.3 ENSP00000003084.6
# Patient_ID
# 01BR001              1.420498         -0.411501               NaN
# 01BR008             -2.042332         -0.577602         -0.340193
# 01BR009             -0.303962          0.235078         -0.705326
# 01BR010             -0.139721          0.271867               NaN
# 01BR015              0.563014          0.146210               NaN
# ...                       ...               ...               ...
# 21BR010              0.367695          0.458972          0.869647
# 22BR005             -0.158708          0.530704               NaN
# 22BR006             -0.804041         -0.213537          1.248475
# CPT000814            1.005284          0.050648               NaN
# CPT001846            0.477857         -1.197101         -1.632624
#
# Name                  CYP51A1  ...             DDHD1               WIZ  \
# Database_ID ENSP00000003100.8  ... ENSP00000500986.2 ENSP00000500993.1
# Patient_ID                     ...
# 01BR001             -0.142503  ...         -1.362787         -1.327957
# 01BR008              0.234808  ...          1.540711               NaN
# 01BR009              0.693133  ...          1.129658               NaN
# 01BR010              1.195923  ...         -0.851456               NaN
# 01BR015             -0.796452  ...          1.028137         -1.143365
# ...                       ...  ...               ...               ...
# 21BR010             -0.059968  ...         -0.281975          1.255194
# 22BR005             -0.263727  ...          1.902622               NaN
# 22BR006              0.928210  ...         -0.074873               NaN
# CPT000814           -0.372543  ...         -4.448773               NaN
# CPT001846            0.848229  ...         -0.023136               NaN
#
# Name                     GBF1             APOA5               WIZ  \
# Database_ID ENSP00000501064.1 ENSP00000501141.1 ENSP00000501256.3
# Patient_ID
# 01BR001             -0.919117               NaN               NaN
# 01BR008              0.105539               NaN               NaN
# 01BR009             -1.372489               NaN               NaN
# 01BR010              1.400585               NaN               NaN
# 01BR015             -0.785598               NaN               NaN
# ...                       ...               ...               ...
# 21BR010              1.031448               NaN         -0.636325
# 22BR005              0.653675               NaN               NaN
# 22BR006              0.666276         -1.616797               NaN
# CPT000814            0.115693               NaN               NaN
# CPT001846            0.971972               NaN               NaN
#
# Name                     LDB1               WIZ              RFX7  \
# Database_ID ENSP00000501277.1 ENSP00000501300.1 ENSP00000501317.1
# Patient_ID
# 01BR001             -1.654606         -0.290793         -0.334686
# 01BR008             -0.120659          0.708855          0.682004
# 01BR009             -0.596078          0.362824          0.782083
# 01BR010             -1.133106         -0.394588          0.387457
# 01BR015              0.109407          3.209620         -0.169682
# ...                       ...               ...               ...
# 21BR010             -0.125450         -0.805658         -0.308279
# 22BR005              0.110199         -0.736742          0.252909
# 22BR006             -0.116793         -0.918482         -0.434764
# CPT000814           -3.302382          2.039134               NaN
# CPT001846            0.009770         -0.080857         -0.770599
#
# Name                   SWSAP1              SVIL
# Database_ID ENSP00000501355.1 ENSP00000501521.1
# Patient_ID
# 01BR001             -1.038080               NaN
# 01BR008             -1.617735               NaN
# 01BR009             -0.702105               NaN
# 01BR010             -1.874066          0.613515
# 01BR015             -0.181832               NaN
# ...                       ...               ...
# 21BR010             -1.002666          0.542512
# 22BR005                   NaN          0.390202
# 22BR006                   NaN          1.057679
# CPT000814                 NaN               NaN
# CPT001846            0.571863               NaN
#
# [122 rows x 12922 columns]

# %%
scaled_dist_stats = prot_scaled.describe().T[['mean','std']]
scaled_dist_stats
# Out:
#                                    mean       std
# Name    Database_ID
# ARF5    ENSP00000000233.5 -5.460113e-18  1.004124
# M6PR    ENSP00000000412.3 -1.072116e-17  1.004124
# ESRRA   ENSP00000000442.6 -3.249433e-17  1.006154
# FKBP4   ENSP00000001008.4  0.000000e+00  1.004124
# NDUFAF7 ENSP00000002125.4 -7.280151e-18  1.004124
# ...                                 ...       ...
# LDB1    ENSP00000501277.1 -1.192978e-17  1.004124
# WIZ     ENSP00000501300.1 -2.411550e-17  1.004124
# RFX7    ENSP00000501317.1 -1.071268e-17  1.004415
# SWSAP1  ENSP00000501355.1 -1.345725e-17  1.007663
# SVIL    ENSP00000501521.1 -3.483053e-17  1.009950
#
# [12922 rows x 2 columns]

# %% [markdown]
# We'll have to reselect the proteomics data for just the patients of interest rather than separately normalizing them. But let's cross that bridge when we come to it.
# We'll also need to remove Na values.

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
prot_prepped = imputer.fit_transform(prot_scaled)
# Out:
# /opt/anaconda3/envs/bio362/lib/python3.11/site-packages/sklearn/impute/_base.py:637: UserWarning: Skipping features without any observed values: [  676  1320  1479  1698  1727  2692  2710  4034  4100  4113  4888  5598
#   5878  6752  7409  7516  7861  8148  8654  8690  9092  9172  9221  9251
#   9461  9953  9993 10019 10287 10414 10436 10624 11136 11167 11187 11536
#  11920 11923 12122 12157]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
pca = PCA(n_components=2)

x_pca = pca.fit_transform(prot_prepped)
print("Original shape: ", prot_prepped.shape)
print("Reduced shape: ", x_pca.shape)
print("Explained variance ratio: ", sum(pca.explained_variance_ratio_))
# Out:
# Original shape:  (122, 12882)
# Reduced shape:  (122, 2)
# Explained variance ratio:  0.1766521008578622

# %%
# %conda install matplotlib
import matplotlib.pyplot as plt
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.plot(x_pca[:,0], x_pca[:,1], 'o')
plt.show()

# %%
# %store -r genes_per_patient
mut_pca = pd.DataFrame(
    x_pca, 
    index=all_prot.index, 
    columns=['PC1', 'PC2']
)
mut_pca['Mutated_Genes'] = genes_per_patient['Mutated_Genes']
mut_pca
# Out:
#                   PC1        PC2                         Mutated_Genes
# Patient_ID
# 01BR001     18.664470  37.834286                 [ARID1A, FBXW7, TP53]
# 01BR008     56.939423  -7.476572            [FAT4, HOXC13, MYH9, TP53]
# 01BR009     15.430017  14.268707                   [BRCA1, FAT4, TP53]
# 01BR010    -13.015236  -4.802339                        [HRAS, PIK3CA]
# 01BR015     -4.784476  16.165613   [AFDN, MAP2K4, PIK3CA, PTPRD, TP53]
# ...               ...        ...                                   ...
# 21BR010    -34.379568  -6.725676               [MAP2K4, NCOR1, PIK3CA]
# 22BR005      1.640505 -10.220026  [ARID1A, KMT2D, PIK3CA, RUNX1, TP53]
# 22BR006    -24.854491 -17.756276   [ASXL1, CBFB, GATA3, KMT2C, PIK3CA]
# CPT000814   92.986943  23.109901                                   NaN
# CPT001846   21.770034  61.880219                                   NaN
#
# [122 rows x 3 columns]

# %%
#Let's see if patients with mutations in a specific gene cluster together
gene = "TP53"

mut_pca["TP53_mut"] = mut_pca["Mutated_Genes"].apply(
    lambda genes: gene in genes if isinstance(genes, list) else False
)

plt.scatter(
    mut_pca["PC1"],
    mut_pca["PC2"],
    c=mut_pca["TP53_mut"],
    cmap="coolwarm",
    alpha=0.7
)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Colored by TP53 mutation status")
plt.show()

# %%
genes = driver_genes
long_df = pd.concat(
    [
        mut_pca.assign(
            Gene=gene,
            Mutated=mut_pca["Mutated_Genes"].apply(lambda g: gene in g if isinstance(g, list) else False)
        )
        for gene in genes
    ],
    ignore_index=True
)

# %conda install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(
    long_df,
    col="Gene",
    col_wrap=3,
    hue="Mutated",
    height=4,
    sharex=True,
    sharey=True
)

g.map_dataframe(sns.scatterplot, x="PC1", y="PC2", alpha=0.7)
g.add_legend(title="Mutated")
g.set_axis_labels("PC1", "PC2")
plt.show()
# Out:
# Channels:
#  - defaults
#  - bioconda
#  - conda-forge
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/bio362
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     seaborn-0.13.2             |  py311hecd8cb5_3         734 KB
#     ------------------------------------------------------------
#                                            Total:         734 KB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            pkgs/main/osx-64::seaborn-0.13.2-py311hecd8cb5_3
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
prot_pca = pd.DataFrame(
    x_pca, 
    index=all_prot.index, 
    columns=['PC1', 'PC2']
)
prot_pca
# Out:
#                   PC1        PC2
# Patient_ID
# 01BR001     18.664470  37.834286
# 01BR008     56.939423  -7.476572
# 01BR009     15.430017  14.268707
# 01BR010    -13.015236  -4.802339
# 01BR015     -4.784476  16.165613
# ...               ...        ...
# 21BR010    -34.379568  -6.725676
# 22BR005      1.640505 -10.220026
# 22BR006    -24.854491 -17.756276
# CPT000814   92.986943  23.109901
# CPT001846   21.770034  61.880219
#
# [122 rows x 2 columns]

# %%
pca_of_interest = prot_pca.loc[normal_patients]
pca_of_interest
# Out:
#                   PC1        PC2
# Patient_ID
# 01BR023      0.371703 -88.641233
# 01BR025      7.284308 -20.372416
# 03BR002    -25.848344   4.162150
# 03BR005    -52.324981  54.105864
# 05BR001     19.884764  22.815370
# 05BR003    -18.848299  10.158451
# 11BR015      5.952172 -62.815782
# 11BR027    -32.026862 -40.327147
# 11BR049     -4.500974 -11.423860
# 18BR004    -23.417736 -34.589785
# 18BR017    -20.699320  -4.662577

# %%
plt.plot(prot_pca['PC1'], prot_pca['PC2'], 'o')
plt.plot(pca_of_interest['PC1'], pca_of_interest['PC2'], 'o')
plt.show()

# %% [markdown]
# There it is! Our patients without driver mutations or significant copy number variations are in orange, while the other patients are in blue. Looking at this, they don't seem to be clustering differently than the other patients. However, we have to remember that this only shows two principal components that explain only about ~18% of the variance. Let's use an actual metric to see if they're measurably different or not.

# %%
pca_big = PCA(n_components=0.80)

x_pca_big = pca_big.fit_transform(prot_prepped)
print("Original shape: ", prot_prepped.shape)
print("Reduced shape: ", x_pca_big.shape)
print("Explained variance ratio: ", sum(pca_big.explained_variance_ratio_))
# Out:
# Original shape:  (122, 12882)
# Reduced shape:  (122, 56)
# Explained variance ratio:  0.8012253608337598

# %%
prot_pca_big = pd.DataFrame(
    x_pca_big, 
    index=all_prot.index, 
    columns=[f'PC{i+1}' for i in range(x_pca_big.shape[1])]
)
prot_pca_big
# Out:
#                   PC1        PC2        PC3        PC4        PC5        PC6  \
# Patient_ID
# 01BR001     18.664470  37.834304 -22.002390  -4.000175   1.383124 -28.010365
# 01BR008     56.939428  -7.476578  37.911240 -14.279853 -10.845493  29.741104
# 01BR009     15.430019  14.268691  22.433162 -15.106306   0.985129 -26.502354
# 01BR010    -13.015234  -4.802354  38.010860  25.371997  25.096857 -30.288497
# 01BR015     -4.784475  16.165631 -21.846652 -17.299349  28.880760  -7.236303
# ...               ...        ...        ...        ...        ...        ...
# 21BR010    -34.379566  -6.725663 -11.425015   5.572647   9.431136   3.463847
# 22BR005      1.640500 -10.220018   2.251381   5.959224   6.309769   7.638904
# 22BR006    -24.854488 -17.756272  17.165346   9.163895   3.483937   3.036527
# CPT000814   92.986946  23.109886 -47.392317  26.918190  -5.352979 -19.543252
# CPT001846   21.770038  61.880208 -10.083571  33.573055  -9.821948 -35.008044
#
#                   PC7        PC8        PC9       PC10  ...       PC47  \
# Patient_ID                                              ...
# 01BR001     25.296863  16.589772 -12.275858   1.668591  ...  19.682059
# 01BR008     14.672611   9.407763  28.198879  -3.412375  ...  -0.121598
# 01BR009     35.239801  16.371766   9.829559   7.648004  ... -12.120776
# 01BR010     21.195547  23.003506  23.518332  -6.198892  ...   8.734407
# 01BR015     -5.795147   9.814044  10.593645 -16.655148  ...   7.653116
# ...               ...        ...        ...        ...  ...        ...
# 21BR010    -12.559075  -9.515858   3.576053   2.854779  ...   8.668003
# 22BR005     -0.319947   0.773120  -6.723185  -2.033552  ...   8.071766
# 22BR006     -0.767983 -13.861299   2.675734   6.576622  ...  -6.905718
# CPT000814  -14.836396 -43.906684  -3.729484 -13.627613  ...   5.350640
# CPT001846   -4.728943 -40.422573 -14.826043 -31.460643  ...   0.304760
#
#                  PC48       PC49      PC50       PC51       PC52       PC53  \
# Patient_ID
# 01BR001      6.033110  17.473019  2.061120  -6.368664   2.883361  17.211640
# 01BR008      4.492079  -6.617804  4.954146   1.415676  -3.872976   4.028963
# 01BR009      2.997410   8.446618  4.623991   9.258409 -22.282783  -2.433408
# 01BR010      1.580830  -7.690022 -3.281728  -2.923612   0.551130   6.960156
# 01BR015     -5.498044   7.538824 -7.736555  -1.297800  -0.101617  -2.205660
# ...               ...        ...       ...        ...        ...        ...
# 21BR010      2.578895   6.819437 -6.582937  -9.369883  -7.052636   4.684262
# 22BR005     -3.517882   5.427792  1.064409   4.649297  -0.372357   3.240487
# 22BR006     -3.233214   5.498115 -2.218905  -3.099217   4.733029   8.683617
# CPT000814  -15.071643  -5.513930 -5.315352 -10.372407  -2.350320  -5.365643
# CPT001846   -0.295233   0.353260 -2.081745   4.533732   9.056522  -4.775564
#
#                 PC54       PC55       PC56
# Patient_ID
# 01BR001    -6.636438  -1.270433  13.716338
# 01BR008    -6.092812  -2.047978   2.652008
# 01BR009    -1.657806  -4.600258 -15.299376
# 01BR010    -2.510858   7.272484   6.592647
# 01BR015    -7.009236  -2.660789   2.490820
# ...              ...        ...        ...
# 21BR010     0.074119  -8.052836   1.908434
# 22BR005     7.133763   2.338630  -4.459257
# 22BR006     6.589792  14.976237  -1.582744
# CPT000814  -0.500662  -0.046217  -0.426420
# CPT001846   0.251424  -1.266396  -0.090252
#
# [122 rows x 56 columns]

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
prot_linkage = linkage(prot_pca_big, method='ward', metric='euclidean')
dendro = dendrogram(prot_linkage, labels=prot_pca_big.index, leaf_font_size=3)

# %% [markdown]
# Wow! Look at that! Now we can see which samples are most related to each other. Let's try to highlight our samples and then see if they lie on the same branches.

# %%
dendro = dendrogram(prot_linkage, labels=prot_pca_big.index, leaf_font_size=5)
ax = plt.gca()
for lbl in ax.get_xmajorticklabels():
    if lbl.get_text() in set(normal_patients):
        lbl.set_color('red')
        lbl.set_rotation(90)
    else:
        lbl.set_alpha(0)

# %% [markdown]
# Now, our patients of interest are in red on the bottom.
# Looking at this graph, not much is apparent. In 56 dimensions of principal components, our patients are not that close.
# It would have been interesting if they did group on their own, but it's not surprising. This may indicate a few things.
# Most of these mystery patients, while not having driver mutations, are similar to patients who do have driver mutations. Perhaps they have other mutations that affect the same pathway.
