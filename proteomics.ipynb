# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import scipy.stats as stats
# import pandas as pd
# import numpy as np
# import statistics
import cptac
import pandas

# %%
#cptac.download('pdac')
data = cptac.Brca()
#https://colab.research.google.com/drive/1qpKBlQ2iPhi6XfoJV2avK4f8CaXn5Nnm?usp=sharing#scrollTo=51gf_WxX66Co

# %%
data

# %%
# import cptac.utils as ut
# clin_prot = data.join_metadata_to_omics(
#     "proteomics",          # omics_df_name
#     "clinical",            # metadata_df_name (default, but required positionally)
#     ["Sample_Tumor_Normal"]  # metadata_cols
# )
# #Some functions require that we drop the Database_ID column. 
# no_id = ut.reduce_multiindex(df=clin_prot, levels_to_drop="Database_ID")
# no_id
prot = data.get_proteomics()
prot.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 10
#       1 # import cptac.utils as ut
#       2 # clin_prot = data.join_metadata_to_omics(
#       3 #     "proteomics",          # omics_df_name
#    (...)      8 # no_id = ut.reduce_multiindex(df=clin_prot, levels_to_drop="Database_ID")
#       9 # no_id
# ---> 10 prot = data.get_proteomics()
#      11 prot.head()
#
# File ~/miniconda3/envs/bio362/lib/python3.12/site-packages/cptac/cancers/cancer.py:164, in Cancer.get_proteomics(self, source, tissue_type, imputed)
#     162 def get_proteomics(self, source: str=None, tissue_type: str="both", imputed: bool=False) -> pd.DataFrame:
#     163     """Get the proteomics dataframe from the specified data source."""
# --> 164     return self.get_dataframe("proteomics", source, tissue_type, imputed=imputed)
#
# ...
